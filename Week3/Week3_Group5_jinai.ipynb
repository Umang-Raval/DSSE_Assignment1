# %% [markdown]
# **0. Import requireed modules**

# %%
# !unzip /content/resourcemanager.zip -d /content/resourcemanager_java_files
# Out:
# Archive:  /content/resourcemanager.zip
#    creating: /content/resourcemanager_java_files/resourcemanager/
#   inflating: /content/resourcemanager_java_files/resourcemanager/ActiveStandbyElectorBasedElectorService.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/AdminService.java
#    creating: /content/resourcemanager_java_files/resourcemanager/ahs/
#   inflating: /content/resourcemanager_java_files/resourcemanager/ahs/RMApplicationHistoryWriter.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/ahs/WritingApplicationAttemptFinishEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/ahs/WritingApplicationAttemptStartEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/ahs/WritingApplicationFinishEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/ahs/WritingApplicationHistoryEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/ahs/WritingApplicationStartEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/ahs/WritingContainerFinishEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/ahs/WritingContainerStartEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/ahs/WritingHistoryEventType.java
#    creating: /content/resourcemanager_java_files/resourcemanager/amlauncher/
#   inflating: /content/resourcemanager_java_files/resourcemanager/amlauncher/AMLauncher.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/amlauncher/AMLauncherEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/amlauncher/AMLauncherEventType.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/amlauncher/ApplicationMasterLauncher.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/AMSProcessingChain.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/ApplicationMasterService.java
#    creating: /content/resourcemanager_java_files/resourcemanager/blacklist/
#   inflating: /content/resourcemanager_java_files/resourcemanager/blacklist/BlacklistManager.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/blacklist/DisabledBlacklistManager.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/blacklist/SimpleBlacklistManager.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/ClientRMService.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/ClusterMetrics.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/ClusterMonitor.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/CuratorBasedElectorService.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/DBManager.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/DecommissioningNodesWatcher.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/DefaultAMSProcessor.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/EmbeddedElector.java
#    creating: /content/resourcemanager_java_files/resourcemanager/federation/
#   inflating: /content/resourcemanager_java_files/resourcemanager/federation/FederationClientMethod.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/federation/FederationStateStoreHeartbeat.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/federation/FederationStateStoreService.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/federation/FederationStateStoreServiceMetrics.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/federation/package-info.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/GenericEventTypeMetricsManager.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/IsResourceManagerActiveServlet.java
#    creating: /content/resourcemanager_java_files/resourcemanager/metrics/
#   inflating: /content/resourcemanager_java_files/resourcemanager/metrics/AbstractSystemMetricsPublisher.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/metrics/CombinedSystemMetricsPublisher.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/metrics/NoOpSystemMetricPublisher.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/metrics/package-info.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/metrics/SystemMetricsPublisher.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/metrics/TimelineServiceV1Publisher.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/metrics/TimelineServiceV2Publisher.java
#    creating: /content/resourcemanager_java_files/resourcemanager/monitor/
#    creating: /content/resourcemanager_java_files/resourcemanager/monitor/capacity/
#   inflating: /content/resourcemanager_java_files/resourcemanager/monitor/capacity/AbstractPreemptableResourceCalculator.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/monitor/capacity/AbstractPreemptionEntity.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/monitor/capacity/CapacitySchedulerPreemptionContext.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/monitor/capacity/CapacitySchedulerPreemptionUtils.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/monitor/capacity/FifoCandidatesSelector.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/monitor/capacity/FifoIntraQueuePreemptionPlugin.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/monitor/capacity/IntraQueueCandidatesSelector.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/monitor/capacity/IntraQueuePreemptionComputePlugin.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/monitor/capacity/PreemptableResourceCalculator.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/monitor/capacity/PreemptionCandidatesSelector.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/monitor/capacity/ProportionalCapacityPreemptionPolicy.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/monitor/capacity/QueuePriorityContainerCandidateSelector.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/monitor/capacity/ReservedContainerCandidatesSelector.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/monitor/capacity/TempAppPerPartition.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/monitor/capacity/TempQueuePerPartition.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/monitor/capacity/TempSchedulerNode.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/monitor/capacity/TempUserPerPartition.java
#    creating: /content/resourcemanager_java_files/resourcemanager/monitor/invariants/
#   inflating: /content/resourcemanager_java_files/resourcemanager/monitor/invariants/InvariantsChecker.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/monitor/invariants/InvariantViolationException.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/monitor/invariants/MetricsInvariantChecker.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/monitor/invariants/package-info.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/monitor/invariants/ReservationInvariantsChecker.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/monitor/SchedulingEditPolicy.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/monitor/SchedulingMonitor.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/monitor/SchedulingMonitorManager.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/NMLivelinessMonitor.java
#    creating: /content/resourcemanager_java_files/resourcemanager/nodelabels/
#   inflating: /content/resourcemanager_java_files/resourcemanager/nodelabels/FileSystemNodeAttributeStore.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/nodelabels/NodeAttributesManagerImpl.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/nodelabels/NodeAttributesStoreEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/nodelabels/NodeAttributesStoreEventType.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/nodelabels/NodeLabelsUtils.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/nodelabels/RMDelegatedNodeLabelsUpdater.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/nodelabels/RMNodeLabelsManager.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/nodelabels/RMNodeLabelsMappingProvider.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/NodesListManager.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/NodesListManagerEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/NodesListManagerEventType.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/OpportunisticContainerAllocatorAMService.java
#    creating: /content/resourcemanager_java_files/resourcemanager/placement/
#   inflating: /content/resourcemanager_java_files/resourcemanager/placement/ApplicationPlacementContext.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/placement/CSMappingPlacementRule.java
#    creating: /content/resourcemanager_java_files/resourcemanager/placement/csmappingrule/
#   inflating: /content/resourcemanager_java_files/resourcemanager/placement/csmappingrule/MappingRule.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/placement/csmappingrule/MappingRuleAction.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/placement/csmappingrule/MappingRuleActionBase.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/placement/csmappingrule/MappingRuleActions.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/placement/csmappingrule/MappingRuleConditionalVariable.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/placement/csmappingrule/MappingRuleConditionalVariables.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/placement/csmappingrule/MappingRuleMatcher.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/placement/csmappingrule/MappingRuleMatchers.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/placement/csmappingrule/MappingRuleResult.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/placement/csmappingrule/MappingRuleResultType.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/placement/csmappingrule/MappingRuleValidationContext.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/placement/csmappingrule/MappingRuleValidationContextImpl.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/placement/csmappingrule/MappingRuleValidationHelper.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/placement/DefaultPlacementRule.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/placement/FairQueuePlacementUtils.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/placement/FSPlacementRule.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/placement/PlacementFactory.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/placement/PlacementManager.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/placement/PlacementRule.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/placement/PrimaryGroupPlacementRule.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/placement/QueueMapping.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/placement/QueuePlacementRuleUtils.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/placement/RejectPlacementRule.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/placement/SecondaryGroupExistingPlacementRule.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/placement/SpecifiedPlacementRule.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/placement/UserPlacementRule.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/placement/VariableContext.java
#    creating: /content/resourcemanager_java_files/resourcemanager/preprocessor/
#   inflating: /content/resourcemanager_java_files/resourcemanager/preprocessor/ContextProcessor.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/preprocessor/NodeLabelProcessor.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/preprocessor/package-info.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/preprocessor/QueueProcessor.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/preprocessor/SubmissionContextPreProcessor.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/preprocessor/TagAddProcessor.java
#    creating: /content/resourcemanager_java_files/resourcemanager/recovery/
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/FileSystemRMStateStore.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/LeveldbRMStateStore.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/MemoryRMStateStore.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/NullRMStateStore.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/package-info.java
#    creating: /content/resourcemanager_java_files/resourcemanager/recovery/records/
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/records/AMRMTokenSecretManagerState.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/records/ApplicationAttemptStateData.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/records/ApplicationStateData.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/records/Epoch.java
#    creating: /content/resourcemanager_java_files/resourcemanager/recovery/records/impl/
#    creating: /content/resourcemanager_java_files/resourcemanager/recovery/records/impl/pb/
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/records/impl/pb/AMRMTokenSecretManagerStatePBImpl.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/records/impl/pb/ApplicationAttemptStateDataPBImpl.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/records/impl/pb/ApplicationStateDataPBImpl.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/records/impl/pb/EpochPBImpl.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/records/RMDelegationTokenIdentifierData.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/Recoverable.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/RMStateStore.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/RMStateStoreAMRMTokenEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/RMStateStoreAppAttemptEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/RMStateStoreAppEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/RMStateStoreEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/RMStateStoreEventType.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/RMStateStoreFactory.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/RMStateStoreProxyCAEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/RMStateStoreRemoveAppAttemptEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/RMStateStoreRemoveAppEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/RMStateStoreRMDTEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/RMStateStoreRMDTMasterKeyEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/RMStateStoreStoreReservationEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/RMStateStoreUtils.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/RMStateUpdateAppAttemptEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/RMStateUpdateAppEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/RMStateVersionIncompatibleException.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/StoreFencedException.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/StoreLimitException.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/ZKRMStateStore.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/recovery/ZKRMStateStoreOpDurations.java
#    creating: /content/resourcemanager_java_files/resourcemanager/reservation/
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/AbstractReservationSystem.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/AbstractSchedulerPlanFollower.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/CapacityOverTimePolicy.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/CapacityReservationSystem.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/CapacitySchedulerPlanFollower.java
#    creating: /content/resourcemanager_java_files/resourcemanager/reservation/exceptions/
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/exceptions/ContractValidationException.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/exceptions/PlanningException.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/exceptions/PlanningQuotaException.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/exceptions/ResourceOverCommitException.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/FairReservationSystem.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/FairSchedulerPlanFollower.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/InMemoryPlan.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/InMemoryReservationAllocation.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/NoOverCommitPolicy.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/PeriodicRLESparseResourceAllocation.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/Plan.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/PlanContext.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/PlanEdit.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/PlanFollower.java
#    creating: /content/resourcemanager_java_files/resourcemanager/reservation/planning/
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/planning/AlignedPlannerWithGreedy.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/planning/GreedyReservationAgent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/planning/IterativePlanner.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/planning/Planner.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/planning/PlanningAlgorithm.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/planning/ReservationAgent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/planning/SimpleCapacityReplanner.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/planning/StageAllocator.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/planning/StageAllocatorGreedy.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/planning/StageAllocatorGreedyRLE.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/planning/StageAllocatorLowCostAligned.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/planning/StageExecutionInterval.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/planning/StageExecutionIntervalByDemand.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/planning/StageExecutionIntervalUnconstrained.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/planning/TryManyReservationAgents.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/PlanView.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/ReservationAllocation.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/ReservationConstants.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/ReservationInputValidator.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/ReservationInterval.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/ReservationSchedulerConfiguration.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/ReservationSystem.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/ReservationSystemUtil.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/RLESparseResourceAllocation.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/reservation/SharingPolicy.java
#    creating: /content/resourcemanager_java_files/resourcemanager/resource/
#   inflating: /content/resourcemanager_java_files/resourcemanager/resource/DynamicResourceConfiguration.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/resource/ResourceProfilesManager.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/resource/ResourceProfilesManagerImpl.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/ResourceManager.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/ResourceManagerMXBean.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/ResourceTrackerService.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/RMActiveServiceContext.java
#    creating: /content/resourcemanager_java_files/resourcemanager/rmapp/
#    creating: /content/resourcemanager_java_files/resourcemanager/rmapp/attempt/
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmapp/attempt/AggregateAppResourceUsage.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmapp/attempt/AMLivelinessMonitor.java
#    creating: /content/resourcemanager_java_files/resourcemanager/rmapp/attempt/event/
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmapp/attempt/event/RMAppAttemptContainerFinishedEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmapp/attempt/event/RMAppAttemptRegistrationEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmapp/attempt/event/RMAppAttemptStatusupdateEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmapp/attempt/event/RMAppAttemptUnregistrationEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmapp/attempt/RMAppAttempt.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmapp/attempt/RMAppAttemptEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmapp/attempt/RMAppAttemptEventType.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmapp/attempt/RMAppAttemptImpl.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmapp/attempt/RMAppAttemptMetrics.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmapp/attempt/RMAppAttemptState.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmapp/attempt/RMAppStartAttemptEvent.java
#    creating: /content/resourcemanager_java_files/resourcemanager/rmapp/monitor/
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmapp/monitor/package-info.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmapp/monitor/RMAppLifetimeMonitor.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmapp/monitor/RMAppToMonitor.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmapp/RMApp.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmapp/RMAppEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmapp/RMAppEventType.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmapp/RMAppFailedAttemptEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmapp/RMAppImpl.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmapp/RMAppKillByClientEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmapp/RMAppLogAggregation.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmapp/RMAppMetrics.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmapp/RMAppNodeUpdateEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmapp/RMAppRecoverEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmapp/RMAppRunningOnNodeEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmapp/RMAppState.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/RMAppManager.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/RMAppManagerEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/RMAppManagerEventType.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/RMAuditLogger.java
#    creating: /content/resourcemanager_java_files/resourcemanager/rmcontainer/
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmcontainer/AllocationExpirationInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmcontainer/ContainerAllocationExpirer.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmcontainer/RMContainer.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmcontainer/RMContainerEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmcontainer/RMContainerEventType.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmcontainer/RMContainerFinishedEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmcontainer/RMContainerImpl.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmcontainer/RMContainerNMDoneChangeResourceEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmcontainer/RMContainerRecoverEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmcontainer/RMContainerReservedEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmcontainer/RMContainerState.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmcontainer/RMContainerUpdatesAcquiredEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/RMContext.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/RMContextImpl.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/RMCriticalThreadUncaughtExceptionHandler.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/RMFatalEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/RMFatalEventType.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/RMInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/RMInfoMXBean.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/RMNMInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/RMNMInfoBeans.java
#    creating: /content/resourcemanager_java_files/resourcemanager/rmnode/
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmnode/RMNode.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmnode/RMNodeCleanAppEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmnode/RMNodeCleanContainerEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmnode/RMNodeDecommissioningEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmnode/RMNodeEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmnode/RMNodeEventType.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmnode/RMNodeFinishedContainersPulledByAMEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmnode/RMNodeImpl.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmnode/RMNodeReconnectEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmnode/RMNodeResourceUpdateEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmnode/RMNodeSignalContainerEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmnode/RMNodeStartedEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmnode/RMNodeStatusEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmnode/RMNodeUpdateContainerEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/rmnode/UpdatedContainerInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/RMSecretManagerService.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/RMServerUtils.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/RMServiceContext.java
#    creating: /content/resourcemanager_java_files/resourcemanager/scheduler/
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/AbstractResourceUsage.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/AbstractUsersManager.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/AbstractYarnScheduler.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/ActiveUsersManager.java
#    creating: /content/resourcemanager_java_files/resourcemanager/scheduler/activities/
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/activities/ActivitiesLogger.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/activities/ActivitiesManager.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/activities/ActivitiesUtils.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/activities/ActivityDiagnosticConstant.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/activities/ActivityLevel.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/activities/ActivityNode.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/activities/ActivityState.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/activities/AllocationActivity.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/activities/AllocationState.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/activities/AppAllocation.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/activities/DiagnosticsCollector.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/activities/GenericDiagnosticsCollector.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/activities/NodeAllocation.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/Allocation.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/ApplicationPlacementAllocatorFactory.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/AppSchedulingInfo.java
#    creating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/AbsoluteResourceCapacityCalculator.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/AbstractAutoCreatedLeafQueue.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/AbstractCSQueue.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/AbstractLeafQueue.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/AbstractManagedParentQueue.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/AbstractParentQueue.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/AbstractQueueCapacityCalculator.java
#    creating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/allocator/
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/allocator/AbstractContainerAllocator.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/allocator/AllocationState.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/allocator/ContainerAllocation.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/allocator/ContainerAllocator.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/allocator/RegularContainerAllocator.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/AppPriorityACLConfigurationParser.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/AppPriorityACLGroup.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/AutoCreatedLeafQueue.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/AutoCreatedLeafQueueConfig.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/AutoCreatedQueueDeletionPolicy.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/AutoCreatedQueueManagementPolicy.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/AutoCreatedQueueTemplate.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/CalculationContext.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/CapacityHeadroomProvider.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/CapacityScheduler.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/CapacitySchedulerConfiguration.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/CapacitySchedulerConfigValidator.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/CapacitySchedulerContext.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/CapacitySchedulerMetrics.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/CapacitySchedulerQueueCapacityHandler.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/CapacitySchedulerQueueContext.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/CapacitySchedulerQueueManager.java
#    creating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/conf/
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/conf/ConfigurationUpdateAssembler.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/conf/CSConfigurationProvider.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/conf/FileBasedCSConfigurationProvider.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/conf/FSSchedulerConfigurationStore.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/conf/InMemoryConfigurationStore.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/conf/LeveldbConfigurationStore.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/conf/MutableCSConfigurationProvider.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/conf/package-info.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/conf/QueueAdminConfigurationMutationACLPolicy.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/conf/QueueCapacityConfigParser.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/conf/YarnConfigurationStore.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/conf/YarnConfigurationStoreFactory.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/conf/YarnConfStoreVersionIncompatibleException.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/conf/ZKConfigurationStore.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/ConfigurationProperties.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/ConfiguredNodeLabels.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/CSAMContainerLaunchDiagnosticsConstants.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/CSAssignment.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/CSMaxRunningAppsEnforcer.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/CSQueue.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/CSQueueInfoProvider.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/CSQueueMetrics.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/CSQueuePreemptionSettings.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/CSQueueStore.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/CSQueueUsageTracker.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/CSQueueUtils.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/DefaultQueueResourceRoundingStrategy.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/LeafQueue.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/ManagedParentQueue.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/ParentQueue.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/PercentageQueueCapacityCalculator.java
#    creating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/placement/
#    creating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/placement/converter/
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/placement/converter/LegacyMappingRuleToJson.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/placement/GeneratePojos.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/placement/MappingRuleCreator.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/placement/package-info.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/PlanQueue.java
#    creating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/policy/
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/policy/PriorityUtilizationQueueOrderingPolicy.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/policy/QueueOrderingPolicy.java
#    creating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/preemption/
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/preemption/KillableContainer.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/preemption/PreemptableQueue.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/preemption/PreemptionManager.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/QueueAllocationSettings.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/QueueAppLifetimeAndLimitSettings.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/QueueCapacities.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/QueueCapacityUpdateContext.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/QueueCapacityVector.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/QueueConfigurationAutoRefreshPolicy.java
#    creating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/queuemanagement/
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/queuemanagement/DeactivatedLeafQueuesByLabel.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/queuemanagement/GuaranteedOrZeroCapacityOverTimePolicy.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/queuemanagement/LeafQueueEntitlements.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/queuemanagement/package-info.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/QueueManagementChange.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/QueueManagementDynamicEditPolicy.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/QueueNodeLabelsSettings.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/QueuePath.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/QueuePrefixes.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/QueueResourceRoundingStrategy.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/QueueStateHelper.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/QueueUpdateWarning.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/ReservationQueue.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/ResourceCalculationDriver.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/ResourceVector.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/RootCalculationDriver.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/RootQueueCapacityCalculator.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/SchedulingMode.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/UserInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/UsersManager.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/UserWeights.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/WeightQueueCapacityCalculator.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/capacity/WorkflowPriorityMappingsManager.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/ClusterNodeTracker.java
#    creating: /content/resourcemanager_java_files/resourcemanager/scheduler/common/
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/common/ApplicationSchedulingConfig.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/common/AssignmentInformation.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/common/ContainerAllocationProposal.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/common/ContainerRequest.java
#    creating: /content/resourcemanager_java_files/resourcemanager/scheduler/common/fica/
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/common/fica/FiCaSchedulerApp.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/common/fica/FiCaSchedulerNode.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/common/PendingAsk.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/common/QueueEntitlement.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/common/ResourceAllocationCommitter.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/common/ResourceCommitRequest.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/common/SchedulerContainer.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/ConfigurationMutationACLPolicy.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/ConfigurationMutationACLPolicyFactory.java
#    creating: /content/resourcemanager_java_files/resourcemanager/scheduler/constraint/
#    creating: /content/resourcemanager_java_files/resourcemanager/scheduler/constraint/algorithm/
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/constraint/algorithm/CircularIterator.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/scheduler/constraint/algorithm/DefaultPlacementAlgorithm.java
#    creating: /content/resourcemanager_java_files/resourcemanager/scheduler/constraint/algorithm/iterators/
# ...
#   inflating: /content/resourcemanager_java_files/resourcemanager/volume/csi/event/ControllerPublishVolumeEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/volume/csi/event/package-info.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/volume/csi/event/ValidateVolumeEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/volume/csi/event/VolumeEvent.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/volume/csi/event/VolumeEventType.java
#    creating: /content/resourcemanager_java_files/resourcemanager/volume/csi/lifecycle/
#   inflating: /content/resourcemanager_java_files/resourcemanager/volume/csi/lifecycle/package-info.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/volume/csi/lifecycle/Volume.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/volume/csi/lifecycle/VolumeImpl.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/volume/csi/lifecycle/VolumeState.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/volume/csi/package-info.java
#    creating: /content/resourcemanager_java_files/resourcemanager/volume/csi/processor/
#   inflating: /content/resourcemanager_java_files/resourcemanager/volume/csi/processor/package-info.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/volume/csi/processor/VolumeAMSProcessor.java
#    creating: /content/resourcemanager_java_files/resourcemanager/volume/csi/provisioner/
#   inflating: /content/resourcemanager_java_files/resourcemanager/volume/csi/provisioner/package-info.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/volume/csi/provisioner/VolumeProvisioner.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/volume/csi/provisioner/VolumeProvisioningResults.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/volume/csi/provisioner/VolumeProvisioningTask.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/volume/csi/VolumeBuilder.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/volume/csi/VolumeManager.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/volume/csi/VolumeManagerImpl.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/volume/csi/VolumeStates.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/volume/package-info.java
#    creating: /content/resourcemanager_java_files/resourcemanager/webapp/
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/AboutBlock.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/AboutPage.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/AppAttemptPage.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/ApplicationsRequestBuilder.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/AppLogAggregationStatusPage.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/AppPage.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/AppsBlockWithMetrics.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/CapacitySchedulerPage.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/ColumnHeader.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/ContainerPage.java
#    creating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/ActivitiesInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/ActivityNodeInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/AllocationTagInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/AllocationTagsInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/AppActivitiesInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/AppAllocationInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/AppAttemptInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/AppAttemptsInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/AppInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/ApplicationStatisticsInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/ApplicationSubmissionContextInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/AppPriority.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/AppQueue.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/AppRequestAllocationInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/AppsInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/AppState.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/AppTimeoutInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/AppTimeoutsInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/AutoQueueTemplatePropertiesInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/BulkActivitiesInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/CapacitySchedulerHealthInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/CapacitySchedulerInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/CapacitySchedulerLeafQueueInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/CapacitySchedulerQueueInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/CapacitySchedulerQueueInfoList.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/ClusterInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/ClusterMetricsInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/ClusterUserInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/ConfigVersionInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/ContainerLaunchContextInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/CredentialsInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/DelegationToken.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/ExecutionTypeRequestInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/FairSchedulerInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/FairSchedulerLeafQueueInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/FairSchedulerQueueInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/FairSchedulerQueueInfoList.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/FifoSchedulerInfo.java
#    creating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/helper/
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/helper/CapacitySchedulerInfoHelper.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/helper/package-info.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/LabelsToNodesInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/LeafQueueTemplateInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/LocalResourceInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/LogAggregationContextInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/NewApplication.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/NewReservation.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/NodeAllocationInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/NodeAttributeInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/NodeAttributesInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/NodeInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/NodeLabelInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/NodeLabelsInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/NodesInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/NodeToLabelsEntry.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/NodeToLabelsEntryList.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/NodeToLabelsInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/package-info.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/PartitionInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/PartitionQueueCapacitiesInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/PartitionResourcesInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/QueueAclInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/QueueAclsInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/QueueCapacitiesInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/QueueCapacityVectorEntryInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/QueueCapacityVectorInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/ReservationDefinitionInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/ReservationDeleteRequestInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/ReservationDeleteResponseInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/ReservationInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/ReservationListInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/ReservationRequestInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/ReservationRequestsInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/ReservationSubmissionRequestInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/ReservationUpdateRequestInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/ReservationUpdateResponseInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/ResourceAllocationInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/ResourceInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/ResourceInformationsInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/ResourceOptionInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/ResourceRequestInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/ResourcesInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/ResourceUtilizationInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/RMQueueAclInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/SchedulerInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/SchedulerOverviewInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/SchedulerTypeInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/StatisticsItemInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/UserMetricsInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/dao/UsersInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/DefaultSchedulerPage.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/DeSelectFields.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/ErrorBlock.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/FairSchedulerAppsBlock.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/FairSchedulerPage.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/JAXBContextResolver.java
#    creating: /content/resourcemanager_java_files/resourcemanager/webapp/jsonprovider/
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/jsonprovider/ClassSerialisationConfig.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/jsonprovider/ExcludeRootJSONProvider.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/jsonprovider/IncludeRootJSONProvider.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/jsonprovider/JsonProviderFeature.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/MetricsOverviewTable.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/NavBlock.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/NodeIDsInfo.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/NodeLabelsPage.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/NodesPage.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/RedirectionErrorPage.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/RMAppAttemptBlock.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/RMAppBlock.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/RMAppLogAggregationStatusBlock.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/RMAppsBlock.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/RMContainerBlock.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/RmController.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/RMErrorsAndWarningsPage.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/RmView.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/RMWebApp.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/RMWebAppFilter.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/RMWebAppUtil.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/RMWebServiceProtocol.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/RMWebServices.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/RMWSConsts.java
#   inflating: /content/resourcemanager_java_files/resourcemanager/webapp/SchedulerPageUtil.java

# %%
pip install -U bitsandbytes>=0.46.1

# %%
import numpy as np
import torch
from pathlib import Path
from transformers import AutoTokenizer, AutoModel, BitsAndBytesConfig
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.cluster import AgglomerativeClustering
from google.colab import userdata
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch
from collections import defaultdict
import json

# %% [markdown]
# **1. Provide the path of java files and load their source code into a list**

# %%
SOURCE_CODE_DIR = Path("/content/resourcemanager_java_files/resourcemanager")  # upload your java files folder here
OUTPUT_DIR = Path("/content/output")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# %%
files_list = []   # stores file content
file_paths = []   # stores file paths (needed to match back to class names later)

for file_path in SOURCE_CODE_DIR.rglob('*.java'):
    if file_path.is_file():
        with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
            files_list.append(f.read())
            file_paths.append(str(file_path))

print(f"Total Java files loaded: {len(files_list)}")
# Out:
# Total Java files loaded: 749

# %% [markdown]
# **2. Retrieve the Hugging Face token securely from Colab's "Secrets" tab (the key icon on the left).**

# %%
try:
    hf_token = userdata.get('HF_TOKEN')
except userdata.SecretNotFoundError:
    print("WARNING: 'HF_TOKEN' not found in Colab Secrets.")
    hf_token = None

# %% [markdown]
# **3. Hardware optimization (Quantization)**

# %%
# The model WEIGHTS are loaded in 4-bit, reducing memory from ~6GB to ~1.5GB
# This is needed to fit the embedding model alongside other operations on the T4 GPU
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4"
)

# %% [markdown]
# **4. Generate embeddings**

# %%
# Group 5 primary embedding model
embedding_model_name = "jinaai/jina-code-embeddings-0.5b"

# %%
print(f"Loading tokenizer for {embedding_model_name}...")

tokenizer = AutoTokenizer.from_pretrained(
    embedding_model_name,
    token=hf_token,
    trust_remote_code=True
)

print("Loading model...")

model = AutoModel.from_pretrained(
    embedding_model_name,
    token=hf_token,
    trust_remote_code=True,
    device_map="auto"
)

device = torch.device(
    "cuda" if torch.cuda.is_available() else "cpu"
)

model.to(device)

print(f"Using device: {device}")
# Out:
# Loading tokenizer for jinaai/jina-code-embeddings-0.5b...
# Loading model...
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]
# Using device: cuda

# %% [markdown]
# **5. Construct the semantic similarity matrix**

# %%
def embed_source_code(code_files):

    embeddings = []

    for i, code in enumerate(code_files):

        print(f"Embedding file {i+1}/{len(code_files)}...", end="\r")

        inputs = tokenizer(
            code,
            padding=True,
            truncation=True,
            max_length=512,
            return_tensors="pt"
        ).to(device)

        with torch.no_grad():

            outputs = model(**inputs)

        # Mean pooling
        embedding = outputs.last_hidden_state.mean(dim=1)

        embeddings.append(
            embedding.float().cpu().numpy()[0]
        )

    return np.array(embeddings)

# %%
embeddings = embed_source_code(files_list)

semantic_matrix = cosine_similarity(embeddings)

print("Semantic matrix shape:")
print(semantic_matrix.shape)
# Out:
# Semantic matrix shape:
# (749, 749)

# %% [markdown]
# **6. Construct the structural similarity matrix**

# %%
# scan the filtered .rsf dependency file from week 1 to construct a matrix where each entry is the number of packages each pair of files depend on.
# executing this cell produces 'struct_matrix_raw'
# Upload filtered_rsf.rsf to Colab first
RSF_PATH = "/content/filtered_rsf.rsf"

# Build an index mapping file paths to matrix positions
# We match class names from the RSF to file paths from Cell 1
def class_to_file_index(file_paths):
    """Map fully qualified class name to its index in file_paths list"""
    index = {}
    for i, fp in enumerate(file_paths):
        # Convert path like .../org/apache/hadoop/mapreduce/Job.java
        # to org.apache.hadoop.mapreduce.Job
        parts = fp.replace("/", ".").replace("\\", ".")
        for j in range(len(parts)):
            if "org.apache.hadoop" in parts[j:]:
                class_name = parts[j:].replace(".java", "")
                class_name = class_name[class_name.find("org.apache.hadoop"):]
                index[class_name] = i
                break
    return index

class_index = class_to_file_index(file_paths)
n = len(file_paths)

struct_matrix_raw = np.zeros((n, n))

with open(RSF_PATH, "r") as f:
    for line in f:
        parts = line.strip().split()
        if len(parts) == 3 and parts[0] == "depends":
            src, tgt = parts[1], parts[2]
            if src in class_index and tgt in class_index:
                i, j = class_index[src], class_index[tgt]
                struct_matrix_raw[i][j] += 1
                struct_matrix_raw[j][i] += 1  # make it symmetric

print(f"Structural matrix shape: {struct_matrix_raw.shape}")
print(f"Non-zero entries: {np.count_nonzero(struct_matrix_raw)}")
np.save("/content/output/struct_matrix_raw.npy", struct_matrix_raw)
print("✅ Structural matrix saved.")
# Out:
# Structural matrix shape: (749, 749)
# Non-zero entries: 0
# ✅ Structural matrix saved.

# %% [markdown]
# **7. Normalize the structural matrix**

# %%
max_overlap = struct_matrix_raw.max()
struct_matrix = struct_matrix_raw / max_overlap if max_overlap > 0 else struct_matrix_raw
np.fill_diagonal(struct_matrix, 1.0)
print(f"Structural matrix normalized. Max value: {struct_matrix.max():.3f}, Min: {struct_matrix.min():.3f}")
# Out:
# Structural matrix normalized. Max value: 1.000, Min: 0.000

# %% [markdown]
# **8. Combine the two matrices into one similarity matrix then apply complement.**

# %%
# ALPHA: weight of structural vs semantic similarity
# 0.5 = 50% structural + 50% semantic
# Tune this based on your evaluation results
ALPHA = 0.5

combined_similarity = (ALPHA * struct_matrix) + ((1 - ALPHA) * semantic_matrix)

# Invert to get distance matrix (required for AgglomerativeClustering with precomputed metric)
distance_matrix = 1.0 - combined_similarity
np.fill_diagonal(distance_matrix, 0)

print(f"Combined similarity range: {combined_similarity.min():.3f} – {combined_similarity.max():.3f}")
print(f"Distance matrix range: {distance_matrix.min():.3f} – {distance_matrix.max():.3f}")
np.save("/content/output/distance_matrix.npy", distance_matrix)
print("✅ Distance matrix saved.")
# Out:
# Combined similarity range: 0.156 – 1.000
# Distance matrix range: 0.000 – 0.844
# ✅ Distance matrix saved.

# %% [markdown]
# **9. Apply clustering**

# %%
# TARGET_NUM_CLUSTERS:
# Tune later using a2a and cvg

TARGET_NUM_CLUSTERS = 10

clusterer = AgglomerativeClustering(
    n_clusters=TARGET_NUM_CLUSTERS,
    metric='precomputed',
    linkage='average'
)

clusters = clusterer.fit_predict(distance_matrix)

# Save ARC clustering output
rsf_output_path = "/content/output/semantic_clusters.rsf"

with open(rsf_output_path, "w") as f:

    for file_idx, cluster_id in enumerate(clusters):

        class_name = file_paths[file_idx]

        class_name = class_name.replace("/", ".")
        class_name = class_name.replace("\\", ".")

        if "org.apache.hadoop" in class_name:

            class_name = class_name[
                class_name.find("org.apache.hadoop") :
            ]

        class_name = class_name.replace(".java", "")

        f.write(
            f"contain cluster{cluster_id} {class_name}\n"
        )

print(f"✅ Clustering done!")
print(f"✅ RSF saved to: {rsf_output_path}")
# Out:
# ✅ Clustering done!
# ✅ RSF saved to: /content/output/semantic_clusters.rsf

# %% [markdown]
# **10. Visulizations**

# %%
# According to the applied algorithm documentation, provide any visualizations for better understanding of how the clusters are formed.
# 1. Dendrogram — shows how files were merged into clusters
plt.figure(figsize=(16, 6))
linked = sch.linkage(distance_matrix, method='average')
sch.dendrogram(linked, no_labels=True)
plt.title("Agglomerative Clustering Dendrogram (Jina Embeddings)")
plt.xlabel("Source Files")
plt.ylabel("Distance")
plt.tight_layout()
plt.savefig("/content/output/dendrogram.png", dpi=150)
plt.show()

# 2. Cluster size distribution
unique, counts = np.unique(clusters, return_counts=True)
plt.figure(figsize=(14, 4))
plt.bar(unique, counts, color="steelblue")
plt.title("Cluster Size Distribution")
plt.xlabel("Cluster ID")
plt.ylabel("Number of Files")
plt.tight_layout()
plt.savefig("/content/output/cluster_sizes.png", dpi=150)
plt.show()

# 3. Heatmap of combined similarity matrix (sampled for visibility)
sample_size = min(100, len(file_paths))
plt.figure(figsize=(10, 8))
plt.imshow(combined_similarity[:sample_size, :sample_size], cmap="hot", interpolation="nearest")
plt.colorbar(label="Similarity")
plt.title(f"Combined Similarity Matrix (first {sample_size} files)")
plt.tight_layout()
plt.savefig("/content/output/similarity_heatmap.png", dpi=150)
plt.show()

print("✅ All visualizations saved to /content/output/")
# Out:
# /tmp/ipykernel_631/627440151.py:4: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   linked = sch.linkage(distance_matrix, method='average')
# ✅ All visualizations saved to /content/output/
